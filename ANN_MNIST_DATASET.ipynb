# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
(x_train, y_train) , (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
x_train_flattened = x_train.reshape(len(x_train), 28*28)

# %%
x_test_flattened = x_test.reshape(len(x_test), 28*28)

# %%
model = keras.Sequential([
  keras.layers.Dense(1000, input_shape = (784,), activation = 'sigmoid'),
  keras.layers.Dense(10, activation = 'sigmoid')
])
model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = 'accuracy'
)
model.fit(x_train_flattened, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 16s 8ms/step - loss: 0.3292 - accuracy: 0.9041
# Epoch 2/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1636 - accuracy: 0.9517
# Epoch 3/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1028 - accuracy: 0.9687
# Epoch 4/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0703 - accuracy: 0.9784
# Epoch 5/10
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.0500 - accuracy: 0.9844
# Epoch 6/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0358 - accuracy: 0.9885
# Epoch 7/10
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.0261 - accuracy: 0.9920
# Epoch 8/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0187 - accuracy: 0.9946
# Epoch 9/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0139 - accuracy: 0.9961
# Epoch 10/10
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.0117 - accuracy: 0.9967

# %%
y_predicted = model.predict(x_test_flattened)
y_predicted_labels = [np.argmax(i) for i in y_predicted]

# %%
model.evaluate(x_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0664 - accuracy: 0.9812
# [0.06637772917747498, 0.9811999797821045]

# %%
tf.math.confusion_matrix(labels = y_test, predictions = y_predicted_labels)
# Out:
# <tf.Tensor: shape=(10, 10), dtype=int32, numpy=
# array([[ 960,    0,    1,    2,    0,    5,    6,    3,    2,    1],
#        [   0, 1118,    3,    2,    0,    1,    4,    2,    5,    0],
#        [   6,   11,  909,   22,    9,    5,   11,   12,   44,    3],
#        [   1,    0,   13,  933,    1,   21,    2,   10,   23,    6],
#        [   1,    2,    2,    2,  920,    0,   12,    4,    8,   31],
#        [   9,    3,    2,   43,   11,  762,   13,    8,   35,    6],
#        [  11,    3,    6,    1,    7,   12,  912,    2,    4,    0],
#        [   1,    6,   22,    8,    6,    0,    0,  959,    2,   24],
#        [   5,   14,    5,   22,    9,   19,    8,   14,  873,    5],
#        [  10,    7,    1,   12,   31,    5,    0,   28,    8,  907]],
#       dtype=int32)>
